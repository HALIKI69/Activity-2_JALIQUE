# %% [markdown]
# <a href="https://colab.research.google.com/github/HALIKI69/Activity-2_JALIQUE/blob/main/coconut%20collab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # select coconut_yolo_dataset.zip from your computer
# Out:
#      <input type="file" id="files-3c7afa0c-552a-401f-a432-ff402649122e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3c7afa0c-552a-401f-a432-ff402649122e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q coconut_yolo_dataset.zip -d /content/
# Out:
# unzip:  cannot find or open coconut_yolo_dataset.zip, coconut_yolo_dataset.zip.zip or coconut_yolo_dataset.zip.ZIP.

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 18370, done.
# remote: Counting objects: 100% (55/55), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 18370 (delta 36), reused 18 (delta 18), pack-reused 18315 (from 3)
# Receiving objects: 100% (18370/18370), 17.48 MiB | 19.56 MiB/s, done.
# Resolving deltas: 100% (12481/12481), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 88.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 15.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
yaml_content = """path: /content/yolo_dataset
train: images/train
val: images/val

nc: 1
names: ['COCONUT']
"""

with open('/content/yolo_dataset/data.yaml', 'w') as f:
    f.write(yaml_content)

print(open('/content/yolo_dataset/data.yaml').read())
# Out:
# path: /content/yolo_dataset
# train: images/train
# val: images/val
#
# nc: 1
# names: ['COCONUT']

# %%
# !python train.py --img 640 --batch 8 --epochs 100 \
  --data /content/yolo_dataset/data.yaml \
  --weights yolov5s.pt \
  --name coconut_baseline
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: izakaelmatas (izakaelmatas-university-of-mindanao) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# ...

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls yolov5/runs/train/coconut_baseline/weights/best.pt
# Out:
# ls: cannot access 'yolov5/runs/train/coconut_baseline/weights/best.pt': No such file or directory

# %%
# !cp runs/train/coconut_baseline2/weights/best.pt /content/drive/MyDrive/best.pt
# Out:
# cp: cannot stat 'runs/train/coconut_baseline2/weights/best.pt': No such file or directory
